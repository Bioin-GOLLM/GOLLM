# %%
# Cell 1: Import Libraries
import pandas as pd
import os

# %% [markdown]
# ## Download the PMIDS->PMCIDS mapping from the PMC FTP site. this will be the pmc_ids_file variable in the cell after this
# [Website link to PMC-ids.csv.gz](https://ftp.ncbi.nlm.nih.gov/pub/pmc/) for pmid to pmcid mapping
#
# [Website link to oa_comm_use_file_list.csv](https://ftp.ncbi.nlm.nih.gov/pub/pmc/) for pmcid to pmcid (open access + commercial use) mapping

# %%
# Cell 2: Define File Paths
# Define input and output directories
subsets_dir = r"C:\Users\aivan\Desktop\BIOIN 401\GOLLM\data\matching_pmids_subsets"  # Directory with subset files
pmc_ids_file = r"C:\Users\aivan\Downloads\PMC-ids.csv.gz"  # .gz file
oa_comm_use_file_list = r"C:\Users\aivan\Downloads\oa_comm_use_file_list.csv"
output_dir = r"C:\Users\aivan\Desktop\BIOIN 401\GOLLM\data\matching_pmcids_subsets"  # Output directory

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# %%
# Cell 3: Load PMC-ids.csv.gz
print("Loading PMC-ids.csv.gz...")
pmc_ids = pd.read_csv(
    pmc_ids_file,
    usecols=["PMCID", "PMID"],
    dtype=str,
    compression="gzip"
)
print("PMC-ids.csv.gz loaded successfully!")
# Out:
# Loading PMC-ids.csv.gz...
# PMC-ids.csv.gz loaded successfully!

# %%
# Cell 4: Load Open Access PMCIDs
print("Loading Open Access PMCIDs from oa_file_list.csv...")
oa_pmc_ids = pd.read_csv(oa_comm_use_file_list, usecols=["Accession ID"], dtype=str)
oa_pmc_set = set(oa_pmc_ids["Accession ID"])  # Convert to set for fast lookup
print("Open Access PMCIDs loaded successfully!")
# Out:
# Loading Open Access PMCIDs from oa_file_list.csv...
# Open Access PMCIDs loaded successfully!

# %%
# Cell 5: Process Each Subset File
# Loop through each subset file in the directory
for subset_file in os.listdir(subsets_dir):
    if subset_file.endswith(".txt"):  # Ensure it's a .txt file
        subset_path = os.path.join(subsets_dir, subset_file)

        # Extract the subset number from the file name
        subset_number = os.path.splitext(subset_file)[0].split('_')[-1]
        output_file = os.path.join(output_dir, f"subset_{subset_number}.txt")

        # Step 1: Load the subset of PMIDs
        print(f"Loading subset file: {subset_file}...")
        subset_pmids = pd.read_csv(subset_path, header=None, names=["PMID"], dtype=str)

        # Step 2: Perform the matching (PMID → PMCID)
        print(f"Matching PMIDs with PMCIDs for {subset_file}...")
        matched = pd.merge(subset_pmids, pmc_ids, on="PMID", how="left")

        # Step 3: Keep only Open Access PMCIDs
        matched["is_open_access"] = matched["PMCID"].isin(oa_pmc_set)
        matched_oa = matched[matched["is_open_access"]]  # Filter only OA PMCIDs

        # Step 4: Save the result to a .txt file
        print(f"Saving Open Access results to: subset_{subset_number}.txt...")
        with open(output_file, "w", encoding="utf-8") as f:
            for _, row in matched_oa.iterrows():
                pmid = row["PMID"]
                pmcid = row["PMCID"] if pd.notna(row["PMCID"]) else "NA"
                f.write(f"{pmid}\t{pmcid}\n")  # Tab-separated values

print("Done! All subsets processed. Only Open Access PMCIDs (commercial use) are saved.")
# Out:
# Loading subset file: subset_1.txt...
# Matching PMIDs with PMCIDs for subset_1.txt...
# Saving Open Access results to: subset_1.txt...
# Loading subset file: subset_10.txt...
# Matching PMIDs with PMCIDs for subset_10.txt...
# Saving Open Access results to: subset_10.txt...
# Loading subset file: subset_11.txt...
# Matching PMIDs with PMCIDs for subset_11.txt...
# Saving Open Access results to: subset_11.txt...
# Loading subset file: subset_12.txt...
# Matching PMIDs with PMCIDs for subset_12.txt...
# Saving Open Access results to: subset_12.txt...
# Loading subset file: subset_13.txt...
# Matching PMIDs with PMCIDs for subset_13.txt...
# Saving Open Access results to: subset_13.txt...
# Loading subset file: subset_14.txt...
# Matching PMIDs with PMCIDs for subset_14.txt...
# Saving Open Access results to: subset_14.txt...
# Loading subset file: subset_15.txt...
# Matching PMIDs with PMCIDs for subset_15.txt...
# Saving Open Access results to: subset_15.txt...
# Loading subset file: subset_16.txt...
# Matching PMIDs with PMCIDs for subset_16.txt...
# Saving Open Access results to: subset_16.txt...
# Loading subset file: subset_17.txt...
# Matching PMIDs with PMCIDs for subset_17.txt...
# Saving Open Access results to: subset_17.txt...
# Loading subset file: subset_18.txt...
# Matching PMIDs with PMCIDs for subset_18.txt...
# Saving Open Access results to: subset_18.txt...
# Loading subset file: subset_19.txt...
# Matching PMIDs with PMCIDs for subset_19.txt...
# Saving Open Access results to: subset_19.txt...
# Loading subset file: subset_2.txt...
# Matching PMIDs with PMCIDs for subset_2.txt...
# Saving Open Access results to: subset_2.txt...
# Loading subset file: subset_20.txt...
# Matching PMIDs with PMCIDs for subset_20.txt...
# Saving Open Access results to: subset_20.txt...
# Loading subset file: subset_21.txt...
# Matching PMIDs with PMCIDs for subset_21.txt...
# Saving Open Access results to: subset_21.txt...
# Loading subset file: subset_22.txt...
# Matching PMIDs with PMCIDs for subset_22.txt...
# Saving Open Access results to: subset_22.txt...
# Loading subset file: subset_23.txt...
# Matching PMIDs with PMCIDs for subset_23.txt...
# Saving Open Access results to: subset_23.txt...
# Loading subset file: subset_24.txt...
# Matching PMIDs with PMCIDs for subset_24.txt...
# Saving Open Access results to: subset_24.txt...
# Loading subset file: subset_25.txt...
# Matching PMIDs with PMCIDs for subset_25.txt...
# Saving Open Access results to: subset_25.txt...
# Loading subset file: subset_26.txt...
# Matching PMIDs with PMCIDs for subset_26.txt...
# Saving Open Access results to: subset_26.txt...
# Loading subset file: subset_27.txt...
# Matching PMIDs with PMCIDs for subset_27.txt...
# Saving Open Access results to: subset_27.txt...
# Loading subset file: subset_28.txt...
# Matching PMIDs with PMCIDs for subset_28.txt...
# Saving Open Access results to: subset_28.txt...
# Loading subset file: subset_29.txt...
# Matching PMIDs with PMCIDs for subset_29.txt...
# Saving Open Access results to: subset_29.txt...
# Loading subset file: subset_3.txt...
# Matching PMIDs with PMCIDs for subset_3.txt...
# Saving Open Access results to: subset_3.txt...
# Loading subset file: subset_30.txt...
# Matching PMIDs with PMCIDs for subset_30.txt...
# Saving Open Access results to: subset_30.txt...
# Loading subset file: subset_31.txt...
# Matching PMIDs with PMCIDs for subset_31.txt...
# Saving Open Access results to: subset_31.txt...
# Loading subset file: subset_32.txt...
# Matching PMIDs with PMCIDs for subset_32.txt...
# Saving Open Access results to: subset_32.txt...
# Loading subset file: subset_33.txt...
# Matching PMIDs with PMCIDs for subset_33.txt...
# Saving Open Access results to: subset_33.txt...
# Loading subset file: subset_34.txt...
# Matching PMIDs with PMCIDs for subset_34.txt...
# Saving Open Access results to: subset_34.txt...
# Loading subset file: subset_35.txt...
# Matching PMIDs with PMCIDs for subset_35.txt...
# Saving Open Access results to: subset_35.txt...
# Loading subset file: subset_36.txt...
# Matching PMIDs with PMCIDs for subset_36.txt...
# Saving Open Access results to: subset_36.txt...
# Loading subset file: subset_37.txt...
# Matching PMIDs with PMCIDs for subset_37.txt...
# Saving Open Access results to: subset_37.txt...
# Loading subset file: subset_38.txt...
# Matching PMIDs with PMCIDs for subset_38.txt...
# Saving Open Access results to: subset_38.txt...
# Loading subset file: subset_39.txt...
# Matching PMIDs with PMCIDs for subset_39.txt...
# Saving Open Access results to: subset_39.txt...
# Loading subset file: subset_4.txt...
# Matching PMIDs with PMCIDs for subset_4.txt...
# Saving Open Access results to: subset_4.txt...
# Loading subset file: subset_40.txt...
# Matching PMIDs with PMCIDs for subset_40.txt...
# Saving Open Access results to: subset_40.txt...
# Loading subset file: subset_41.txt...
# Matching PMIDs with PMCIDs for subset_41.txt...
# Saving Open Access results to: subset_41.txt...
# Loading subset file: subset_42.txt...
# Matching PMIDs with PMCIDs for subset_42.txt...
# Saving Open Access results to: subset_42.txt...
# Loading subset file: subset_43.txt...
# Matching PMIDs with PMCIDs for subset_43.txt...
# Saving Open Access results to: subset_43.txt...
# Loading subset file: subset_44.txt...
# Matching PMIDs with PMCIDs for subset_44.txt...
# Saving Open Access results to: subset_44.txt...
# Loading subset file: subset_45.txt...
# Matching PMIDs with PMCIDs for subset_45.txt...
# Saving Open Access results to: subset_45.txt...
# Loading subset file: subset_46.txt...
# Matching PMIDs with PMCIDs for subset_46.txt...
# Saving Open Access results to: subset_46.txt...
# Loading subset file: subset_47.txt...
# Matching PMIDs with PMCIDs for subset_47.txt...
# Saving Open Access results to: subset_47.txt...
# Loading subset file: subset_48.txt...
# Matching PMIDs with PMCIDs for subset_48.txt...
# Saving Open Access results to: subset_48.txt...
# Loading subset file: subset_49.txt...
# Matching PMIDs with PMCIDs for subset_49.txt...
# Saving Open Access results to: subset_49.txt...
# Loading subset file: subset_5.txt...
# Matching PMIDs with PMCIDs for subset_5.txt...
# Saving Open Access results to: subset_5.txt...
# Loading subset file: subset_50.txt...
# Matching PMIDs with PMCIDs for subset_50.txt...
# Saving Open Access results to: subset_50.txt...
# Loading subset file: subset_51.txt...
# Matching PMIDs with PMCIDs for subset_51.txt...
# Saving Open Access results to: subset_51.txt...
# Loading subset file: subset_52.txt...
# Matching PMIDs with PMCIDs for subset_52.txt...
# Saving Open Access results to: subset_52.txt...
# Loading subset file: subset_53.txt...
# Matching PMIDs with PMCIDs for subset_53.txt...
# Saving Open Access results to: subset_53.txt...
# Loading subset file: subset_54.txt...
# Matching PMIDs with PMCIDs for subset_54.txt...
# Saving Open Access results to: subset_54.txt...
# Loading subset file: subset_55.txt...
# Matching PMIDs with PMCIDs for subset_55.txt...
# Saving Open Access results to: subset_55.txt...
# Loading subset file: subset_56.txt...
# Matching PMIDs with PMCIDs for subset_56.txt...
# Saving Open Access results to: subset_56.txt...
# Loading subset file: subset_57.txt...
# Matching PMIDs with PMCIDs for subset_57.txt...
# Saving Open Access results to: subset_57.txt...
# Loading subset file: subset_58.txt...
# Matching PMIDs with PMCIDs for subset_58.txt...
# Saving Open Access results to: subset_58.txt...
# Loading subset file: subset_59.txt...
# Matching PMIDs with PMCIDs for subset_59.txt...
# Saving Open Access results to: subset_59.txt...
# Loading subset file: subset_6.txt...
# Matching PMIDs with PMCIDs for subset_6.txt...
# Saving Open Access results to: subset_6.txt...
# Loading subset file: subset_7.txt...
# Matching PMIDs with PMCIDs for subset_7.txt...
# Saving Open Access results to: subset_7.txt...
# Loading subset file: subset_8.txt...
# Matching PMIDs with PMCIDs for subset_8.txt...
# Saving Open Access results to: subset_8.txt...
# Loading subset file: subset_9.txt...
# Matching PMIDs with PMCIDs for subset_9.txt...
# Saving Open Access results to: subset_9.txt...
# Done! All subsets processed. Only Open Access PMCIDs (commercial use) are saved.
